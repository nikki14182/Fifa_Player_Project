# %%
import pandas as pd
import numpy as np

# %%
# load csv file into notebook 

soccer_df = pd.read_csv(r'C:/Users/nlrob/OneDrive/Desktop/JUMPRO Project/players_20.csv')

#show top 5 records
soccer_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# show columns in dataset

#list(soccer_df.columns)

column_name = [i for i in soccer_df.columns]

column_name
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
soccer_df.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
# show number of rows and columns in dataset

soccer_df.shape # 18,278 rows and 104 columns
# Out:
# (18278, 104)

# %%
soccer_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# show number of players and their countries

soccer_df['short_name'].count() #18,278 players

soccer_df['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
# top 10 countries with the most soccer players

soccer_df['nationality'].value_counts().nlargest(10)
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
# create bar plot of top 5 countries and number of players

soccer_df['nationality'].value_counts().nlargest(5).plot.bar(color= 'green')
# Out:
# <AxesSubplot:>

# %%
soccer_df.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
# show top 5 players and wages

soccer_df[['wage_eur','short_name']].nlargest(5, 'wage_eur')
# Out:
#     wage_eur         short_name
# 0     565000           L. Messi
# 4     470000          E. Hazard
# 1     405000  Cristiano Ronaldo
# 5     370000       K. De Bruyne
# 22    370000       A. Griezmann

# %%
# show top 5 players and wages that have the highest salaries

soccer_df[['value_eur','short_name']].nlargest(5, 'value_eur')
# Out:
#     value_eur    short_name
# 2   105500000     Neymar Jr
# 0    95500000      L. Messi
# 10   93500000     K. Mbappé
# 4    90000000     E. Hazard
# 5    90000000  K. De Bruyne

# %%
# create bar plot of players with the highest salaries

soccer_df[['value_eur','short_name']].nlargest(5, 'value_eur').plot.bar(color= 'orange')
# Out:
# <AxesSubplot:>

# %%
# show top 10 records of Germany

soccer_df.loc[soccer_df['nationality'] == 'Germany'].head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
soccer_df.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
# top 5 records of Germany players with the max height, weight, and wages

soccer_df.loc[soccer_df['nationality'] == 'Germany', ['height_cm', 'weight_kg', 'wage_eur']].sort_values('height_cm', ascending=False).head()
# Out:
#        height_cm  weight_kg  wage_eur
# 8016         199         90      9000
# 1217         198         97     23000
# 1389         198        103     14000
# 11859        197         94      2000
# 13576        197        103      2000

# %%
# name and wages of top 5 Germany players

soccer_df.loc[soccer_df['nationality'] == 'Germany', ['short_name', 'wage_eur']].sort_values('wage_eur', ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
# show top 5 players who have great shooting skills

soccer_df.loc[soccer_df['shooting'] >= 70.0, ['short_name']] #.sort_values('shooting',ascending=False)
# Out:
#               short_name
# 0               L. Messi
# 1      Cristiano Ronaldo
# 2              Neymar Jr
# 4              E. Hazard
# 5           K. De Bruyne
# ...                  ...
# 8718        Alex Doneiro
# 9026         Samuel Dias
# 9089        S. Nicholson
# 9685            I. Yagan
# 10124        S. Demhasaj
#
# [1572 rows x 1 columns]

# %%
soccer_df.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
# show top 5 player record(name, defending, nationality, and club) with great defending skills
soccer_df.groupby(['short_name','defending', 'nationality', 'club'])

# %%
soccer_df['defending']
# Out:
# 0        39.0
# 1        35.0
# 2        32.0
# 3         NaN
# 4        35.0
#          ...
# 18273    47.0
# 18274    48.0
# 18275    48.0
# 18276    45.0
# 18277    47.0
# Name: defending, Length: 18278, dtype: float64

# %%
# show wage records of top 5 players of 'Real Madrid' team

soccer_df.loc[soccer_df['club'] == 'Real Madrid', ['short_name', 'wage_eur']].sort_values('wage_eur', ascending=False).head()
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %%
# show shooting records of top 5 players of 'Real Madrid' team
soccer_df.loc[soccer_df['club'] == 'Real Madrid', ['short_name', 'shooting']].sort_values('shooting', ascending=False).head()
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
# show defending records of top 5 players of 'Real madrid' team

soccer_df.loc[soccer_df['club'] == 'Real Madrid', ['short_name', 'defending']].sort_values('defending', ascending=False).head()
# Out:
#        short_name  defending
# 18   Sergio Ramos       87.0
# 42       Casemiro       85.0
# 76      R. Varane       85.0
# 94       Carvajal       82.0
# 332  Éder Militão       81.0

# %%
# show nationality records of top 5 players of 'Real Madrid' team
soccer_df.loc[soccer_df['club'] == 'Real Madrid', ['short_name', 'nationality','overall']].sort_values('overall', ascending=False).head()
# Out:
#       short_name nationality  overall
# 4      E. Hazard     Belgium       91
# 8      L. Modrić     Croatia       90
# 18  Sergio Ramos       Spain       89
# 28   T. Courtois     Belgium       88
# 36      T. Kroos     Germany       88
